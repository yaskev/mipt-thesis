# %%
# https://www.barchart.com/futures/quotes/HOJ24/options/JATJ24?moneyness=20

import pandas as pd
import numpy as np

# %%
march = pd.read_csv('30_04_24.csv')
# march['spot_strike_ratio'] = 1 / march['spot_strike_ratio']

march.sort_values('spot_strike_ratio', inplace=True)

march.to_csv('30_04_24_fixed.csv', index=False, float_format='%.4f')

# %%
ks = 2.532 / np.array([2.22,2.27,2.4,2.41,2.44,2.48,2.49,2.5,2.52,2.53,2.54,2.55,2.65,2.75,2.8,2.9,3,3.02,3.1,3.15,3.3,3.5])

# %%
print(',\n'.join([str(k) for k in ks]))
# Out:
# 1.1405405405405404,
# 1.1154185022026433,
# 1.0550000000000002,
# 1.0506224066390042,
# 1.0377049180327869,
# 1.020967741935484,
# 1.016867469879518,
# 1.0128,
# 1.0047619047619047,
# 1.000790513833992,
# 0.9968503937007874,
# 0.9929411764705883,
# 0.9554716981132075,
# 0.9207272727272727,
# 0.9042857142857144,
# 0.8731034482758621,
# 0.844,
# 0.83841059602649,
# 0.8167741935483871,
# 0.8038095238095239,
# 0.7672727272727273,
# 0.7234285714285714

# %%
prices = np.array([0.3654, 0.3278,0.2401,0.2340,0.2163,0.1940,0.1887,0.1834,0.1732,0.1683,0.1634,0.1587,0.1165,0.0846,0.0717, 0.0509, 0.0356,0.0330,0.0245,0.0202,0.0112,0.0048])

# %%
print(prices / ks)
# Out:
# [0.32037441 0.29388073 0.22758294 0.22272512 0.20844076 0.1900158
#  0.18556991 0.18108215 0.17237915 0.16816706 0.16391627 0.1598282
#  0.1219293  0.09188389 0.0792891  0.05829779 0.04218009 0.03936019
#  0.02999605 0.02513033 0.01459716 0.00663507]

# %%
ks = 2.565 / np.array([2.22,2.27,2.28,2.34,2.37,2.4,2.41,2.44,2.45,2.48,2.49,2.5,2.52,2.53,2.54,2.55,2.58,2.6,2.65,2.75,2.78,2.8,2.83,2.88,2.9,3,3.02,3.1,3.15,3.3,3.5])

# %%
print(',\n'.join([str(k) for k in ks]))
# Out:
# 1.1554054054054053,
# 1.1299559471365639,
# 1.125,
# 1.0961538461538463,
# 1.0822784810126582,
# 1.06875,
# 1.0643153526970954,
# 1.0512295081967213,
# 1.046938775510204,
# 1.034274193548387,
# 1.0301204819277108,
# 1.026,
# 1.0178571428571428,
# 1.0138339920948618,
# 1.0098425196850394,
# 1.0058823529411764,
# 0.9941860465116279,
# 0.9865384615384615,
# 0.9679245283018868,
# 0.9327272727272727,
# 0.9226618705035972,
# 0.9160714285714286,
# 0.9063604240282686,
# 0.890625,
# 0.8844827586206897,
# 0.855,
# 0.8493377483443708,
# 0.8274193548387097,
# 0.8142857142857143,
# 0.7772727272727273,
# 0.7328571428571429

# %%
prices = np.array([0.3648, 0.3245, 0.3166, 0.2705, 0.2489, 0.2283, 0.2217, 0.2025, 0.1963, 0.1785, 0.1728, 0.1672, 0.1563, 0.1511, 0.1461, 0.1411, 0.1273, 0.1187, 0.0993, 0.0693, 0.0621, 0.0577, 0.0515, 0.0426, 0.0395, 0.0264, 0.0243, 0.0173, 0.0139, 0.0070, 0.0025])

# %%
print(prices / ks)
# Out:
# [0.31573333 0.28717934 0.28142222 0.24677193 0.22997778 0.21361404
#  0.20830292 0.19263158 0.18749903 0.1725848  0.16774737 0.16296296
#  0.15355789 0.14903821 0.14467602 0.14027485 0.12804444 0.12031969
#  0.10259064 0.07429825 0.06730526 0.06298635 0.05682066 0.04783158
#  0.04465887 0.03087719 0.02861053 0.02090838 0.01707018 0.00900585
#  0.00341131]

# %%
ks = 2.6  / np.array([2.27, 2.28, 2.34, 2.37, 2.39, 2.4, 2.41, 2.44, 2.48, 2.49, 2.5, 2.52, 2.53, 2.54, 2.55, 2.58, 2.6, 2.65, 2.68,2.74,2.75,2.78,2.8, 2.81,2.83,2.85,2.86,2.88,2.9,2.97,3,3.02,3.1])

# %%
print(',\n'.join([str(k) for k in ks]))
# Out:
# 1.145374449339207,
# 1.1403508771929827,
# 1.1111111111111112,
# 1.0970464135021096,
# 1.0878661087866108,
# 1.0833333333333335,
# 1.0788381742738589,
# 1.0655737704918034,
# 1.0483870967741935,
# 1.0441767068273091,
# 1.04,
# 1.0317460317460319,
# 1.0276679841897234,
# 1.0236220472440944,
# 1.019607843137255,
# 1.0077519379844961,
# 1.0,
# 0.9811320754716982,
# 0.9701492537313433,
# 0.948905109489051,
# 0.9454545454545454,
# 0.9352517985611511,
# 0.9285714285714287,
# 0.9252669039145908,
# 0.9187279151943463,
# 0.9122807017543859,
# 0.9090909090909092,
# 0.9027777777777778,
# 0.896551724137931,
# 0.8754208754208754,
# 0.8666666666666667,
# 0.8609271523178809,
# 0.8387096774193549

# %%
prices = np.array([0.3384, 0.3297, 0.2790, 0.2549, 0.2392, 0.2316, 0.2240,0.2019, 0.1740, 0.1673, 0.1608, 0.1483, 0.1422, 0.1363, 0.1306, 0.1143, 0.1045, 0.0830, 0.0719, 0.0536, 0.0510,0.0437,0.0394,0.0374,0.0336,0.0302,0.0286,0.0257,0.0230,0.0157,0.0133,0.0118,0.0072])

# %%
print(prices / ks)
# Out:
# [0.29544923 0.28912154 0.2511     0.23235115 0.21988    0.21378462
#  0.20763077 0.18947538 0.16596923 0.16022192 0.15461538 0.14373692
#  0.13837154 0.13315462 0.12808846 0.11342077 0.1045     0.08459615
#  0.07411231 0.05648615 0.05394231 0.04672538 0.04243077 0.04042077
#  0.03657231 0.03310385 0.03146    0.02846769 0.02565385 0.01793423
#  0.01534615 0.01370615 0.00858462]
