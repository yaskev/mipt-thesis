# %%
# https://www.barchart.com/futures/quotes/HOJ24/options/JATJ24?moneyness=20

import pandas as pd
import numpy as np

# %%
march = pd.read_csv('31_07_24_v2.csv')
# march['spot_strike_ratio'] = 1 / march['spot_strike_ratio']

march.sort_values('spot_strike_ratio', inplace=True)

march.to_csv('31_07_24_v2_fixed.csv', index=False, float_format='%.4f')

# %%
# June

# %%
ks = 2.525 / np.array([2.22,2.27,2.4,2.41,2.44,2.48,2.49,2.5,2.52,2.53,2.54,2.55,2.65,2.75,2.8,2.9,3,3.02,3.1,3.15,3.3,3.5])

# %%
print(',\n'.join([str(k) for k in ks]))
# Out:
# 1.1373873873873872,
# 1.1123348017621144,
# 1.0520833333333333,
# 1.0477178423236513,
# 1.0348360655737705,
# 1.0181451612903225,
# 1.0140562248995983,
# 1.01,
# 1.001984126984127,
# 0.9980237154150198,
# 0.9940944881889763,
# 0.9901960784313726,
# 0.9528301886792453,
# 0.9181818181818181,
# 0.9017857142857143,
# 0.8706896551724138,
# 0.8416666666666667,
# 0.8360927152317881,
# 0.814516129032258,
# 0.8015873015873016,
# 0.7651515151515151,
# 0.7214285714285714

# %%
prices = np.array([0.3654, 0.3278,0.2401,0.2340,0.2163,0.1940,0.1887,0.1834,0.1732,0.1683,0.1634,0.1587,0.1165,0.0846,0.0717, 0.0509, 0.0356,0.0330,0.0245,0.0202,0.0112,0.0048])

# %%
prices_v2 = np.array([0.3347, 0.2977, 0.2126, 0.2068, 0.1898, 0.1685, 0.1635, 0.1585, 0.1489, 0.1443, 0.1398, 0.1353, 0.0969, 0.0685, 0.0572, 0.0394, 0.0266, 0.0246, 0.0177, 0.0144, 0.0075, 0.0030])

# %%
ks = 2.525 / ks
print(',\n'.join([str(kek) for kek in prices_v2 / ks]))
# Out:
# 0.15076576576576575,
# 0.1311453744493392,
# 0.08858333333333335,
# 0.08580912863070539,
# 0.07778688524590165,
# 0.06794354838709678,
# 0.06566265060240964,
# 0.0634,
# 0.05908730158730159,
# 0.05703557312252965,
# 0.05503937007874016,
# 0.05305882352941177,
# 0.03656603773584906,
# 0.024909090909090912,
# 0.02042857142857143,
# 0.013586206896551723,
# 0.008866666666666667,
# 0.00814569536423841,
# 0.005709677419354839,
# 0.004571428571428572,
# 0.0022727272727272726,
# 0.0008571428571428572

# %%
# May

# %%
ks = 2.565 / np.array([2.22,2.27,2.28,2.34,2.37,2.4,2.41,2.44,2.45,2.48,2.49,2.5,2.52,2.53,2.54,2.55,2.58,2.6,2.65,2.75,2.78,2.8,2.83,2.88,2.9,3,3.02,3.1,3.15,3.3,3.5])

ks_v2 = 2.555 / np.array([2.22,2.27,2.28,2.34,2.37,2.4,2.41,2.44,2.45,2.48,2.49,2.5,2.52,2.53,2.54,2.55,2.58,2.6,2.65,2.75,2.78,2.8,2.83,2.88,2.9,3,3.02,3.1,3.15,3.3,3.5])

# %%
print(',\n'.join([str(k) for k in ks_v2]))
# Out:
# 1.1509009009009008,
# 1.1255506607929515,
# 1.1206140350877194,
# 1.091880341880342,
# 1.0780590717299579,
# 1.0645833333333334,
# 1.0601659751037344,
# 1.0471311475409837,
# 1.042857142857143,
# 1.030241935483871,
# 1.0261044176706826,
# 1.022,
# 1.0138888888888888,
# 1.0098814229249014,
# 1.0059055118110236,
# 1.0019607843137257,
# 0.9903100775193798,
# 0.9826923076923078,
# 0.9641509433962265,
# 0.9290909090909092,
# 0.919064748201439,
# 0.9125000000000001,
# 0.902826855123675,
# 0.8871527777777779,
# 0.8810344827586207,
# 0.8516666666666667,
# 0.8460264900662252,
# 0.8241935483870968,
# 0.8111111111111112,
# 0.7742424242424243,
# 0.7300000000000001

# %%
prices = np.array([0.3648, 0.3245, 0.3166, 0.2705, 0.2489, 0.2283, 0.2217, 0.2025, 0.1963, 0.1785, 0.1728, 0.1672, 0.1563, 0.1511, 0.1461, 0.1411, 0.1273, 0.1187, 0.0993, 0.0693, 0.0621, 0.0577, 0.0515, 0.0426, 0.0395, 0.0264, 0.0243, 0.0173, 0.0139, 0.0070, 0.0025])

# %%
prices_v2 = np.array([0.3339, 0.2938, 0.2860, 0.2411, 0.2202, 0.2005, 0.1941, 0.1758, 0.1700, 0.1531, 0.1478, 0.1426, 0.1326, 0.1279, 0.1233, 0.1188, 0.1062, 0.0985, 0.0812, 0.0553,0.0491, 0.0453, 0.0401, 0.0326, 0.0299, 0.0192, 0.0176, 0.0121, 0.0095, 0.0045, 0.0014])

# %%
ks_v2 = 2.555 / ks_v2
print(prices_v2 / ks_v2)
# Out:
# [0.15040541 0.12942731 0.1254386  0.10303419 0.09291139 0.08354167
#  0.08053942 0.07204918 0.06938776 0.06173387 0.05935743 0.05704
#  0.05261905 0.05055336 0.04854331 0.04658824 0.04116279 0.03788462
#  0.03064151 0.02010909 0.01766187 0.01617857 0.01416961 0.01131944
#  0.01031034 0.0064     0.00582781 0.00390323 0.00301587 0.00136364
#  0.0004    ]

# %%
# April

# %%
ks = 2.6  / np.array([2.27, 2.28, 2.34, 2.37, 2.39, 2.4, 2.41, 2.44, 2.48, 2.49, 2.5, 2.52, 2.53, 2.54, 2.55, 2.58, 2.6, 2.65, 2.68,2.74,2.75,2.78,2.8, 2.81,2.83,2.85,2.86,2.88,2.9,2.97,3,3.02,3.1])

# %%
ks_v2 = 2.5995  / np.array([2.27, 2.28, 2.34, 2.37, 2.39, 2.4, 2.41, 2.44, 2.48, 2.49, 2.5, 2.52, 2.53, 2.54, 2.55, 2.58, 2.6, 2.65, 2.68,2.74,2.75,2.78,2.8, 2.81,2.83,2.85,2.86,2.88,2.9,2.97,3,3.02])

# %%
print(',\n'.join([str(k) for k in ks_v2]))
# Out:
# 1.1451541850220264,
# 1.1401315789473685,
# 1.110897435897436,
# 1.0968354430379745,
# 1.0876569037656902,
# 1.0831250000000001,
# 1.0786307053941908,
# 1.0653688524590164,
# 1.0481854838709677,
# 1.0439759036144578,
# 1.0398,
# 1.031547619047619,
# 1.0274703557312252,
# 1.0234251968503936,
# 1.0194117647058825,
# 1.0075581395348836,
# 0.9998076923076923,
# 0.9809433962264151,
# 0.9699626865671641,
# 0.9487226277372262,
# 0.9452727272727273,
# 0.9350719424460432,
# 0.9283928571428571,
# 0.9250889679715302,
# 0.9185512367491165,
# 0.9121052631578946,
# 0.9089160839160839,
# 0.9026041666666667,
# 0.8963793103448275,
# 0.8752525252525252,
# 0.8664999999999999,
# 0.8607615894039735

# %%
prices = np.array([0.3384, 0.3297, 0.2790, 0.2549, 0.2392, 0.2316, 0.2240,0.2019, 0.1740, 0.1673, 0.1608, 0.1483, 0.1422, 0.1363, 0.1306, 0.1143, 0.1045, 0.0830, 0.0719, 0.0536, 0.0510,0.0437,0.0394,0.0374,0.0336,0.0302,0.0286,0.0257,0.0230,0.0157,0.0133,0.0118,0.0072])

# %%
prices_v2 = np.array([0.3047, 0.2961, 0.2464, 0.2227, 0.2076, 0.2001, 0.1928, 0.1715, 0.1450, 0.1388, 0.1328, 0.1212, 0.1157, 0.1103, 0.1051, 0.0909, 0.0822, 0.0631, 0.0536, 0.0382, 0.0361, 0.0303, 0.0270, 0.0255, 0.0226, 0.0201, 0.0189, 0.0167, 0.0148,0.0096,0.0079, 0.0069])

# %%
ks_v2 = 2.5995 / ks_v2
print(prices_v2 / ks_v2)
# Out:
# [0.13422907 0.12986842 0.10529915 0.09396624 0.08686192 0.083375
#  0.08       0.07028689 0.05846774 0.05574297 0.05312    0.04809524
#  0.04573123 0.0434252  0.04121569 0.03523256 0.03161538 0.02381132
#  0.02       0.01394161 0.01312727 0.01089928 0.00964286 0.00907473
#  0.00798587 0.00705263 0.00660839 0.00579861 0.00510345 0.00323232
#  0.00263333 0.00228477]

# %%
# March

# %%
rate = 0.0630
ttm = 0.06027397260273973
spot = 2.5952

# %%
ks_v2 = spot  / np.array([2.4, 2.44, 2.45, 2.47, 2.48, 2.5,2.51,2.52,2.53,2.54,2.55,2.56,2.57,2.58,2.59,2.6,2.63,2.65,2.67,2.68,2.7,2.72,2.74,2.75,2.77,2.78,2.8])

# %%
prices_v2 = np.array([0.2132, 0.1745, 0.1651, 0.1464, 0.1372, 0.1194, 0.1109, 0.1027, 0.0947, 0.0871, 0.0798, 0.0728, 0.0662, 0.0600, 0.0541, 0.0486, 0.0344, 0.0268, 0.0206, 0.0179, 0.0134, 0.0099, 0.0072, 0.0062, 0.0044, 0.0037, 0.0027])

# %%
price_strike_ratio = prices_v2 * ks_v2 / spot
print(price_strike_ratio)
# Out:
# [0.08883333 0.07151639 0.06738776 0.05927126 0.05532258 0.04776
#  0.04418327 0.04075397 0.03743083 0.03429134 0.03129412 0.0284375
#  0.02575875 0.02325581 0.02088803 0.01869231 0.01307985 0.01011321
#  0.00771536 0.0066791  0.00496296 0.00363971 0.00262774 0.00225455
#  0.00158845 0.00133094 0.00096429]

# %%
for i in range(len(ks_v2)):
  print(','.join([str(ks_v2[i]), str(ttm), str(rate), str(price_strike_ratio[i]), '0', '0', '0']))
# Out:
# 1.0813333333333335,0.06027397260273973,0.063,0.08883333333333333,0,0,0
# 1.0636065573770492,0.06027397260273973,0.063,0.07151639344262295,0,0,0
# 1.059265306122449,0.06027397260273973,0.063,0.06738775510204081,0,0,0
# 1.0506882591093116,0.06027397260273973,0.063,0.05927125506072873,0,0,0
# 1.046451612903226,0.06027397260273973,0.063,0.055322580645161296,0,0,0
# 1.0380800000000001,0.06027397260273973,0.063,0.047760000000000004,0,0,0
# 1.03394422310757,0.06027397260273973,0.063,0.04418326693227092,0,0,0
# 1.02984126984127,0.06027397260273973,0.063,0.04075396825396826,0,0,0
# 1.0257707509881424,0.06027397260273973,0.063,0.037430830039525693,0,0,0
# 1.021732283464567,0.06027397260273973,0.063,0.03429133858267717,0,0,0
# 1.0177254901960786,0.06027397260273973,0.063,0.031294117647058826,0,0,0
# 1.0137500000000002,0.06027397260273973,0.063,0.028437500000000004,0,0,0
# 1.0098054474708174,0.06027397260273973,0.063,0.025758754863813235,0,0,0
# ...

# %%
# July

# %%
rate = 0.0567
ttm = 0.40273972602739727
spot = 2.5141

# %%
ks_v2 = spot  / np.array([2.21,2.37,2.4,2.41,2.44,2.52,2.55,2.57,2.6,2.65,2.69,2.75,2.8,2.85,2.95,3.1,3.2,3.35,3.5])

# %%
prices_v2 = np.array([0.3495, 0.2433, 0.2259, 0.2203,0.2040, 0.1649, 0.1519, 0.1438, 0.1322, 0.1145, 0.1018, 0.0849, 0.0726, 0.0618, 0.0442, 0.0261, 0.0180, 0.0101, 0.0055])

# %%
price_strike_ratio = prices_v2 * ks_v2 / spot
print(price_strike_ratio)
# Out:
# [0.1581448  0.10265823 0.094125   0.09141079 0.08360656 0.06543651
#  0.05956863 0.05595331 0.05084615 0.04320755 0.03784387 0.03087273
#  0.02592857 0.02168421 0.01498305 0.00841935 0.005625   0.00301493
#  0.00157143]

# %%
for i in range(len(ks_v2)):
  print(','.join([str(ks_v2[i]), str(ttm), str(rate), str(price_strike_ratio[i]), '0', '0', '0']))
# Out:
# 1.1376018099547511,0.40273972602739727,0.0567,0.1581447963800905,0,0,0
# 1.060801687763713,0.40273972602739727,0.0567,0.10265822784810126,0,0,0
# 1.0475416666666668,0.40273972602739727,0.0567,0.094125,0,0,0
# 1.0431950207468879,0.40273972602739727,0.0567,0.09141078838174273,0,0,0
# 1.0303688524590164,0.40273972602739727,0.0567,0.08360655737704918,0,0,0
# 0.9976587301587302,0.40273972602739727,0.0567,0.06543650793650793,0,0,0
# 0.9859215686274511,0.40273972602739727,0.0567,0.059568627450980405,0,0,0
# 0.9782490272373542,0.40273972602739727,0.0567,0.055953307392996116,0,0,0
# 0.9669615384615384,0.40273972602739727,0.0567,0.05084615384615385,0,0,0
# 0.9487169811320755,0.40273972602739727,0.0567,0.043207547169811324,0,0,0
# 0.9346096654275093,0.40273972602739727,0.0567,0.03784386617100372,0,0,0
# 0.9142181818181818,0.40273972602739727,0.0567,0.030872727272727274,0,0,0
# 0.8978928571428572,0.40273972602739727,0.0567,0.02592857142857143,0,0,0
# ...

# %%
# Data collected on 22.03.2024

# %%
# March
rate = 0.0531
ttm = 0.0136986301369863
spot = 2.6534

# %%
ks = spot  / np.array([2.47,2.48,2.5,2.51,2.52,2.53,2.54,2.55,2.56,2.57,2.58,2.59,2.6,2.63,2.65,2.67,2.68])

# %%
prices = np.array([0.2062, 0.1962,0.1762,0.1663,0.1563,0.1463,0.1363,0.1263,0.1163,0.1063,0.0963,0.0863,0.0763,0.0464,0.0263,0.0086,0.0032])

# %%
price_strike_ratio = prices * ks / spot
print(price_strike_ratio)
# Out:
# [0.08348178 0.0791129  0.07048    0.06625498 0.06202381 0.05782609
#  0.05366142 0.04952941 0.04542969 0.04136187 0.03732558 0.03332046
#  0.02934615 0.01764259 0.00992453 0.00322097 0.00119403]

# %%
for i in range(len(ks)):
  print(','.join([str(ks[i]), str(ttm), str(rate), str(price_strike_ratio[i]), '0', '0', '0']))
# Out:
# 1.074251012145749,0.0136986301369863,0.0531,0.08348178137651821,0,0,0
# 1.0699193548387096,0.0136986301369863,0.0531,0.07911290322580646,0,0,0
# 1.06136,0.0136986301369863,0.0531,0.07048,0,0,0
# 1.0571314741035858,0.0136986301369863,0.0531,0.0662549800796813,0,0,0
# 1.0529365079365078,0.0136986301369863,0.0531,0.062023809523809516,0,0,0
# 1.0487747035573123,0.0136986301369863,0.0531,0.05782608695652174,0,0,0
# 1.0446456692913386,0.0136986301369863,0.0531,0.05366141732283465,0,0,0
# 1.0405490196078433,0.0136986301369863,0.0531,0.04952941176470589,0,0,0
# 1.036484375,0.0136986301369863,0.0531,0.045429687499999996,0,0,0
# 1.0324513618677043,0.0136986301369863,0.0531,0.04136186770428016,0,0,0
# 1.0284496124031008,0.0136986301369863,0.0531,0.03732558139534884,0,0,0
# 1.0244787644787645,0.0136986301369863,0.0531,0.033320463320463324,0,0,0
# 1.0205384615384614,0.0136986301369863,0.0531,0.029346153846153845,0,0,0
# 1.008897338403042,0.0136986301369863,0.0531,0.0176425855513308,0,0,0
# ...

# %%
df = pd.DataFrame({
  'spot_strike_ratio': ks,
  'ttm': [ttm] * len(ks),
  'risk_free_rate': [rate] * len(ks),
  'price_strike_ratio': price_strike_ratio,
  'volatility': [0] * len(ks),
  'left_ci': [0] * len(ks),
  'right_ci': [0] * len(ks),
})

# %%
df.sort_values('spot_strike_ratio', inplace=True)

df.to_csv('28_03_24_v3.csv', index=False, float_format='%.4f')

# %%
# April
rate = 0.0532
ttm = 0.10410958904109589
spot = 2.6534

# %%
ks = spot  / np.array([2.37,2.39,2.4,2.41,2.44,2.48,2.49,2.5,2.52,2.53,2.54,2.55,2.58,2.6,2.65,2.68,2.74,2.75,2.78,2.8,2.81,2.83,2.85,2.86,2.88,2.9,2.97,3])

prices = np.array([0.2724,0.2539,0.2448,0.2358,0.2094,0.1760,0.1680,0.1601,0.1447,0.1373,0.1300,0.1229,0.1027,0.0904,0.0645,0.0523,0.0336,0.0311,0.0246,0.0209,0.0193,0.0163,0.0138,0.0126,0.0106,0.0088,0.0044,0.0032])

price_strike_ratio = prices * ks / spot
print(price_strike_ratio)
# Out:
# [0.11493671 0.10623431 0.102      0.09784232 0.08581967 0.07096774
#  0.06746988 0.06404    0.05742063 0.05426877 0.0511811  0.04819608
#  0.0398062  0.03476923 0.02433962 0.01951493 0.01226277 0.01130909
#  0.00884892 0.00746429 0.00686833 0.00575972 0.00484211 0.00440559
#  0.00368056 0.00303448 0.00148148 0.00106667]

# %%
for i in range(len(ks)):
  print(','.join([str(ks[i]), str(ttm), str(rate), str(price_strike_ratio[i]), '0', '0', '0']))
# Out:
# 1.11957805907173,0.10410958904109589,0.0532,0.11493670886075949,0,0,0
# 1.1102092050209205,0.10410958904109589,0.0532,0.10623430962343096,0,0,0
# 1.1055833333333334,0.10410958904109589,0.0532,0.10200000000000001,0,0,0
# 1.1009958506224065,0.10410958904109589,0.0532,0.09784232365145228,0,0,0
# 1.0874590163934426,0.10410958904109589,0.0532,0.08581967213114754,0,0,0
# 1.0699193548387096,0.10410958904109589,0.0532,0.07096774193548386,0,0,0
# 1.0656224899598392,0.10410958904109589,0.0532,0.06746987951807229,0,0,0
# 1.06136,0.10410958904109589,0.0532,0.06404,0,0,0
# 1.0529365079365078,0.10410958904109589,0.0532,0.057420634920634914,0,0,0
# 1.0487747035573123,0.10410958904109589,0.0532,0.05426877470355732,0,0,0
# 1.0446456692913386,0.10410958904109589,0.0532,0.051181102362204724,0,0,0
# 1.0405490196078433,0.10410958904109589,0.0532,0.04819607843137256,0,0,0
# 1.0284496124031008,0.10410958904109589,0.0532,0.039806201550387596,0,0,0
# ...

# %%
df = pd.DataFrame({
  'spot_strike_ratio': ks,
  'ttm': [ttm] * len(ks),
  'risk_free_rate': [rate] * len(ks),
  'price_strike_ratio': price_strike_ratio,
  'volatility': [0] * len(ks),
  'left_ci': [0] * len(ks),
  'right_ci': [0] * len(ks),
})

# %%
df.sort_values('spot_strike_ratio', inplace=True)

df.to_csv('30_04_24_v3.csv', index=False, float_format='%.4f')

# %%
# May
rate = 0.0535
ttm = 0.18904109589041096
spot = 2.6585

# %%
ks = spot  / np.array([2.28,2.34,2.37,2.4,2.41,2.44,2.45,2.48,2.49,2.5,2.52,2.53,2.54,2.55,2.58,2.6,2.65,2.75,2.78,2.8,2.83,2.88,2.9,3,3.02,3.1,3.15,3.3])

prices = np.array([0.3488,0.2977,0.2733,0.2499,0.2422,0.2200,0.2127,0.1917,0.1849,0.1782,0.1652,0.1590,0.1529,0.1469,0.1300,0.1195,0.0961,0.0612,0.0534,0.0486,0.0421,0.0327,0.0295,0.0173,0.0155,0.0099,0.0074,0.0031])

price_strike_ratio = prices * ks / spot
print(price_strike_ratio)
# Out:
# [0.15298246 0.12722222 0.11531646 0.104125   0.10049793 0.09016393
#  0.08681633 0.07729839 0.07425703 0.07128    0.06555556 0.06284585
#  0.06019685 0.05760784 0.0503876  0.04596154 0.03626415 0.02225455
#  0.01920863 0.01735714 0.01487633 0.01135417 0.01017241 0.00576667
#  0.00513245 0.00319355 0.00234921 0.00093939]

# %%
for i in range(len(ks)):
  print(','.join([str(ks[i]), str(ttm), str(rate), str(price_strike_ratio[i]), '0', '0', '0']))
# Out:
# 1.1660087719298247,0.18904109589041096,0.0535,0.1529824561403509,0,0,0
# 1.1361111111111113,0.18904109589041096,0.0535,0.12722222222222224,0,0,0
# 1.1217299578059072,0.18904109589041096,0.0535,0.11531645569620252,0,0,0
# 1.1077083333333335,0.18904109589041096,0.0535,0.10412500000000001,0,0,0
# 1.1031120331950208,0.18904109589041096,0.0535,0.10049792531120333,0,0,0
# 1.089549180327869,0.18904109589041096,0.0535,0.09016393442622951,0,0,0
# 1.0851020408163266,0.18904109589041096,0.0535,0.08681632653061225,0,0,0
# 1.071975806451613,0.18904109589041096,0.0535,0.0772983870967742,0,0,0
# 1.0676706827309237,0.18904109589041096,0.0535,0.0742570281124498,0,0,0
# 1.0634000000000001,0.18904109589041096,0.0535,0.07128,0,0,0
# 1.0549603174603175,0.18904109589041096,0.0535,0.06555555555555556,0,0,0
# 1.0507905138339921,0.18904109589041096,0.0535,0.06284584980237154,0,0,0
# 1.0466535433070867,0.18904109589041096,0.0535,0.0601968503937008,0,0,0
# ...

# %%
df = pd.DataFrame({
  'spot_strike_ratio': ks,
  'ttm': [ttm] * len(ks),
  'risk_free_rate': [rate] * len(ks),
  'price_strike_ratio': price_strike_ratio,
  'volatility': [0] * len(ks),
  'left_ci': [0] * len(ks),
  'right_ci': [0] * len(ks),
})

# %%
df.sort_values('spot_strike_ratio', inplace=True)

df.to_csv('31_05_24_v3.csv', index=False, float_format='%.4f')

# %%
# June
rate = 0.0535
ttm = 0.26575342465753427
spot = 2.6187

# %%
ks = spot  / np.array([2.22, 2.27,2.4,2.41,2.44,2.48,2.49,2.5,2.52,2.53,2.54,2.55,2.58,2.6,2.65,2.75,2.8,2.9,3,3.02,3.1,3.15,3.3])

prices = np.array([0.4030, 0.3613,0.2625,0.2555,0.2353,0.2097,0.2036,0.1975,0.1858,0.1801,0.1745,0.1690,0.1532,0.1432,0.1201,0.0830,0.0687,0.0461,0.0302,0.0277,0.0193,0.0154,0.0075])

price_strike_ratio = prices * ks / spot
print(price_strike_ratio)
# Out:
# [0.18153153 0.159163   0.109375   0.1060166  0.09643443 0.08455645
#  0.08176707 0.079      0.07373016 0.07118577 0.06870079 0.06627451
#  0.05937984 0.05507692 0.04532075 0.03018182 0.02453571 0.01589655
#  0.01006667 0.00917219 0.00622581 0.00488889 0.00227273]

# %%
for i in range(len(ks)):
  print(','.join([str(ks[i]), str(ttm), str(rate), str(price_strike_ratio[i]), '0', '0', '0']))
# Out:
# 1.1795945945945945,0.26575342465753427,0.0535,0.1815315315315315,0,0,0
# 1.1536123348017622,0.26575342465753427,0.0535,0.15916299559471367,0,0,0
# 1.0911250000000001,0.26575342465753427,0.0535,0.10937500000000001,0,0,0
# 1.086597510373444,0.26575342465753427,0.0535,0.10601659751037344,0,0,0
# 1.0732377049180328,0.26575342465753427,0.0535,0.09643442622950821,0,0,0
# 1.0559274193548387,0.26575342465753427,0.0535,0.08455645161290323,0,0,0
# 1.0516867469879518,0.26575342465753427,0.0535,0.08176706827309238,0,0,0
# 1.04748,0.26575342465753427,0.0535,0.079,0,0,0
# 1.0391666666666666,0.26575342465753427,0.0535,0.07373015873015872,0,0,0
# 1.0350592885375496,0.26575342465753427,0.0535,0.07118577075098816,0,0,0
# 1.030984251968504,0.26575342465753427,0.0535,0.0687007874015748,0,0,0
# 1.0269411764705882,0.26575342465753427,0.0535,0.06627450980392158,0,0,0
# 1.015,0.26575342465753427,0.0535,0.05937984496124031,0,0,0
# 1.0071923076923077,0.26575342465753427,0.0535,0.05507692307692307,0,0,0
# ...

# %%
df = pd.DataFrame({
  'spot_strike_ratio': ks,
  'ttm': [ttm] * len(ks),
  'risk_free_rate': [rate] * len(ks),
  'price_strike_ratio': price_strike_ratio,
  'volatility': [0] * len(ks),
  'left_ci': [0] * len(ks),
  'right_ci': [0] * len(ks),
})

# %%
df.sort_values('spot_strike_ratio', inplace=True)

df.to_csv('28_06_24_v3.csv', index=False, float_format='%.4f')

# %%
# July
rate = 0.0536
ttm = 0.3561643835616438
spot = 2.6082

# %%
ks = spot  / np.array([2.21,2.37,2.4,2.41,2.44,2.52,2.55,2.57,2.58,2.6,2.65,2.69,2.75,2.8,2.85,2.95,3.1,3.2])

prices = np.array([0.4174,0.2967,0.2763,0.2697,0.2505,0.2039,0.1882,0.1783,0.1734,0.1641,0.1424,0.1266,0.1057,0.0905,0.0772,0.0555,0.0325,0.0222])

price_strike_ratio = prices * ks / spot
print(price_strike_ratio)
# Out:
# [0.18886878 0.12518987 0.115125   0.11190871 0.10266393 0.0809127
#  0.07380392 0.06937743 0.0672093  0.06311538 0.05373585 0.0470632
#  0.03843636 0.03232143 0.02708772 0.01881356 0.01048387 0.0069375 ]

# %%
for i in range(len(ks)):
  print(','.join([str(ks[i]), str(ttm), str(rate), str(price_strike_ratio[i]), '0', '0', '0']))
# Out:
# 1.1801809954751132,0.3561643835616438,0.0536,0.188868778280543,0,0,0
# 1.100506329113924,0.3561643835616438,0.0536,0.12518987341772153,0,0,0
# 1.08675,0.3561643835616438,0.0536,0.115125,0,0,0
# 1.082240663900415,0.3561643835616438,0.0536,0.11190871369294605,0,0,0
# 1.0689344262295082,0.3561643835616438,0.0536,0.1026639344262295,0,0,0
# 1.035,0.3561643835616438,0.0536,0.08091269841269841,0,0,0
# 1.022823529411765,0.3561643835616438,0.0536,0.07380392156862747,0,0,0
# 1.014863813229572,0.3561643835616438,0.0536,0.06937743190661477,0,0,0
# 1.0109302325581395,0.3561643835616438,0.0536,0.0672093023255814,0,0,0
# 1.003153846153846,0.3561643835616438,0.0536,0.0631153846153846,0,0,0
# 0.9842264150943397,0.3561643835616438,0.0536,0.05373584905660377,0,0,0
# 0.9695910780669146,0.3561643835616438,0.0536,0.0470631970260223,0,0,0
# 0.9484363636363636,0.3561643835616438,0.0536,0.03843636363636364,0,0,0
# 0.9315000000000001,0.3561643835616438,0.0536,0.03232142857142857,0,0,0
# ...

# %%
df = pd.DataFrame({
  'spot_strike_ratio': ks,
  'ttm': [ttm] * len(ks),
  'risk_free_rate': [rate] * len(ks),
  'price_strike_ratio': price_strike_ratio,
  'volatility': [0] * len(ks),
  'left_ci': [0] * len(ks),
  'right_ci': [0] * len(ks),
})

# %%
df.sort_values('spot_strike_ratio', inplace=True)

df.to_csv('31_07_24_v3.csv', index=False, float_format='%.4f')
